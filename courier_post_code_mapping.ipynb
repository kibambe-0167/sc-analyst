# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# Out:
# /var/folders/0r/13xz5g6j45589319bn94k47w0000gn/T/ipykernel_32859/3632437423.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
df = pd.read_csv("./courier_post_code_mapping.csv")
df
# Out:
#        PostalCode HubID       LMR  CourierId
# 0               1   PTA     Local  courier_a
# 1               2   PTA     Local  courier_a
# 2               3   PTA     Local  courier_a
# 3               4   PTA     Local  courier_a
# 4               5   PTA     Local  courier_a
# ...           ...   ...       ...        ...
# 12139        7606   OTD  Regional  courier_b
# 12140        8259   OTD  Regional  courier_b
# 12141        8379   OTD  Regional  courier_b
# 12142        8660   OTD  Regional  courier_b
# 12143        9960   OTD  Regional  courier_b
#
# [12144 rows x 4 columns]

# %%
df.duplicated().sum()
# Out:
# 2

# %%
df.isna().sum()
# Out:
# PostalCode    0
# HubID         0
# LMR           1
# CourierId     0
# dtype: int64

# %%
df.isnull().sum()
# Out:
# PostalCode    0
# HubID         0
# LMR           1
# CourierId     0
# dtype: int64

# %%
df['HubID'].unique()
# Out:
# array(['PTA', 'IND', 'RUS', 'KLK', 'PTG', 'WIT', 'NLS', 'ISA', 'HRS',
#        'BLM', 'KIM', 'ZEE', 'PMB', 'RCB', 'DBN', 'ELS', 'UMT', 'PLZ',
#        'BFW', 'GRG', 'CPT', 'SPK', 'UPT', 'WEL', 'OTD'], dtype=object)

# %%
plt.figure(figsize=(6, 4))
sns.countplot(
    data=df,
    x="HubID",
    hue="CourierId",
    # order=df["LMR"].value_counts().index,  # for sorting
)
plt.title("Counts of HubID")
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(8, 4))
sns.countplot(
    data=df,
    x="LMR",
    hue="CourierId",
    # order=df["LMR"].value_counts().index,  # for sorting
)
plt.title("Counts of LMR")
plt.show()
